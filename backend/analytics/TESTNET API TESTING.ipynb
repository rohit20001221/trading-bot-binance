# %%
api_key = "af3321e3f8710e95aeeee677c14ff3e46f4f258ae3b03f920fd9bc0c5b1351bf"
api_secret = "951f23c274a468004ee7e04980c23b96a8a75e584709554de21b6811222b785b"

# %%
from binance.client import Client

# %%
client : Client = Client(api_key, api_secret, testnet=True) #, base_url="https://stream.binancefuture.com")

# %%
from binance.enums import SIDE_BUY, SIDE_SELL, ORDER_TYPE_MARKET

# %%
client.futures_create_order(
    symbol='BTCUSDT',
    side=SIDE_BUY,
    type=ORDER_TYPE_MARKET,
    quantity=0.001,
)
# Out:
# {'orderId': 3195181468,
#  'symbol': 'BTCUSDT',
#  'status': 'NEW',
#  'clientOrderId': '6mLgE4bAYKW1IBjgOL5Fi4',
#  'price': '0',
#  'avgPrice': '0.00000',
#  'origQty': '0.001',
#  'executedQty': '0',
#  'cumQty': '0',
#  'cumQuote': '0',
#  'timeInForce': 'GTC',
#  'type': 'MARKET',
#  'reduceOnly': False,
#  'closePosition': False,
#  'side': 'BUY',
#  'positionSide': 'BOTH',
#  'stopPrice': '0',
#  'workingType': 'CONTRACT_PRICE',
#  'priceProtect': False,
#  'origType': 'MARKET',
#  'updateTime': 1660382577957}

# %%
client.get_klines(
    symbol='BTCUSDT', interval='1m'
)
# Out:
# [[1660352820000,
#   '24495.37000000',
#   '24496.34000000',
#   '24478.49000000',
#   '24481.16000000',
#   '3.71181800',
#   1660352879999,
#   '90883.22682909',
#   125,
#   '1.79737400',
#   '44010.43423809',
#   '0'],
#  [1660352880000,
#   '24481.60000000',
#   '24494.57000000',
#   '24480.85000000',
#   '24494.57000000',
#   '5.60331700',
#   1660352939999,
#   '137206.05242694',
#   182,
#   '5.17087000',
#   '126617.37325780',
#   '0'],
#  [1660352940000,
#   '24494.57000000',
#   '24506.82000000',
#   '24486.08000000',
#   '24503.89000000',
#   '6.22432800',
#   1660352999999,
#   '152504.62614359',
#   140,
#   '3.18533900',
#   '78047.03263747',
#   '0'],
#  [1660353000000,
#   '24503.50000000',
#   '24507.52000000',
#   '24095.65000000',
#   '24471.38000000',
#   '6.71307700',
#   1660353059999,
#   '164317.33903266',
#   197,
#   '2.27656300',
#   '55755.92038033',
#   '0'],
#  [1660353060000,
#   '24470.29000000',
#   '24485.97000000',
#   '24468.14000000',
# ...
